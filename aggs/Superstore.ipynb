# %%
import pandas as pd

# %%
data = pd.read_csv("Superstore.csv")

# %%
data
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
data1 = data[['Discount']]

# %%
data1
# Out:
#       Discount
# 0         0.01
# 1         0.01
# 2         0.03
# 3         0.01
# 4         0.00
# ...        ...
# 9421      0.06
# 9422      0.00
# 9423      0.08
# 9424      0.10
# 9425      0.09
#
# [9426 rows x 1 columns]

# %%
data2 = data[["Discount", "Unit Price" , 'Product Category', "City", "Sales"]]

# %%
data2
# Out:
#       Discount  Unit Price Product Category        City    Sales
# 0         0.01        2.88  Office Supplies     Addison     5.90
# 1         0.01        2.84  Office Supplies   Anacortes    13.01
# 2         0.03        6.68  Office Supplies   Anacortes    49.92
# 3         0.01        5.68  Office Supplies   Anacortes    41.64
# 4         0.00      205.99       Technology   Anacortes  1446.67
# ...        ...         ...              ...         ...      ...
# 9421      0.06       35.89  Office Supplies  Charleston   447.87
# 9422      0.00        3.34  Office Supplies  Charleston    13.23
# 9423      0.08      550.98        Furniture  Charleston  2215.93
# 9424      0.10      105.98        Furniture    Cheyenne   506.50
# 9425      0.09        7.78  Office Supplies    Cheyenne   172.48
#
# [9426 rows x 5 columns]

# %%
x = data2[data2['Product Category'] == 'Technology']

# %%
x
# Out:
#       Discount  Unit Price Product Category       City    Sales
# 4         0.00      205.99       Technology  Anacortes  1446.67
# 6         0.08      120.97       Technology  Anacortes  1451.37
# 12        0.10       85.99       Technology   San Jose  1705.08
# 31        0.05      115.99       Technology   Syracuse   945.99
# 41        0.07       12.99       Technology   Missoula   231.79
# ...        ...         ...              ...        ...      ...
# 9407      0.01      155.99       Technology    Decatur   689.14
# 9414      0.09        8.46       Technology   Fairmont   105.29
# 9415      0.06       30.98       Technology   Fairmont    96.79
# 9417      0.07      115.79       Technology   Fairmont   878.71
# 9419      0.05       35.99       Technology   Fairmont   596.35
#
# [2312 rows x 5 columns]

# %%
x.to_excel('data2.xlsx', index=False)
